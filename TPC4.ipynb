# %% [markdown]
# ### Manisfesto TPC3
# **Identificador:** TPC3
#
# **Título:** Manipulação de frações
#
# **Data de início:** 2021-11-10 **Data do fim:** 2021-11-11
#
# **Supervisor:** José Carlos Leite Ramalho, https://www.di.uminho.pt/~jcr/
#
# **Autor:** Adriana Daniela Coelho da Costa, A96737
#
# **Resumo**
#
# O código apresentado tem como função realizar operações envolvendo frações.
#
# Inicialmente irá aparecer um menu com diversas funções, como por exemplo somar, subtrair, multilicar e dividir frações. Dependendo da opção escolhida o código irá executar o pedido de acordo com as informações dadas pelo utilizador.

# %%
def menu():
    print("""Bem Vindo! :)
    (1) Criar Fração
    (2) Simplificar Fração
    (3) Somar Fração
    (4) Subtrair Fração
    (5) Multiplicar Fração
    (6) Dividir Fração
    (0) Sair""")

def criarFracao(numerador, denominador):
    return(numerador, denominador)

def verFracao(f):
    n, d = f
    print(str(n) , "/" , (d))
    
def mdc(a, b):
    if a < b:
        return mdc(b, a)
    elif a % b == 0:
        return b
    else: 
        return mdc(a, a % b)
    
def simplificarFracao(f):
    n, d = f
    m = mdc(n, d)
    return(int(n/m), int(d/m))

def somarFracao(f1, f2):
    n1, d1 = f1
    n2, d2 = f2
    return(simplificarFracao(criarFracao(n1 * d2 + n2 * d1, d1 * d2)))

def subtrairFracao(f1, f2):
    n1, d1 = f1
    n2, d2 = f2
    return(simplificarFracao(criarFracao(n1 * d2 - n2 * d1, d1 * d2)))

def multiplicarFracao(f1, f2):
    n1, d1 = f1
    n2, d2 = f2
    return(simplificarFracao(criarFracao(n1 * n2, d1 * d2)))

def dividirFracao(f1, f2):
    n1, n2 = f1
    n2, d2 = f2
    return(simplificarFracao(criarFracao(n1 * d2, n2 * d1)))

def criarLista():
    listaF = []
    q = int(input("Quantos elementos tem a sua lista? "))
    for i in range(q):
        n = randrange(1, 100)
        d = randrange(1, 100)
        listaf.append(criarFracao(n, d))
    return listaFracao

def somarLista(listaF):
    soma = (listaF[0])
    for i in range (1, len(listaF)):
        soma = somarFracao(soma, listaF[i])
    return soma
    
    
opcao = "1"
while opcao != "0":
    menu()
    opcao = input("Escolha a sua opção: ")
    if opcao == "1":
        n = int(input("Escolha o numerador: "))
        d = int(input("Escolha o denominador: "))
        criarFracao(n, d)
    elif opcao == "2":
        f = (n, d)
        verFracao(simplificarFracao(f))
    elif opcao == "0":
        print("Até à proxima! :)")
    elif opcao == "3":
        n = int(input("Escolha o numerador: "))
        d = int(input("Escolha o denominador: "))
        f1 = criarFracao(n, d)
        n2 = int(input("Escolha o numerador: "))
        d2 = int(input("Escolha o denominador: "))
        f2 = criarFracao(n2, d2)
        verFracao(somarFracao(f1, f2))
    elif opcao == "4":
        n = int(input("Escolha o numerador: "))
        d = int(input("Escolha o denominador: "))
        f1 = criarFracao(n, dr)
        n2 = int(input("Escolha o numerador: "))
        d2 = int(input("Escolha o denominador: "))
        f2 = criarFracao(n2, d2)
        verFracao(subtrairFracao(f1, f2))
    elif opcao == "5":
        n = int(input("Escolha o numerador: "))
        d = int(input("Escolha o denominador: "))
        f1 = criarFracao(n, d)
        n2 = int(input("Escolha o numerador: "))
        d2 = int(input("Escolha o denominador: "))
        f2 = criarFracao(n2, d2)
        verFracao(multiplicarFracao(f1, f2))
    elif opcao == "6":
        n = int(input("Escolha o numerador: "))
        d = int(input("Escolha o denominador: "))
        f1 = criarFracao(n, d)
        n2 = int(input("Escolha o numerador: "))
        d2 = int(input("Escolha o denominador: "))
        f2 = criarFracao(n2, d2)
        verFracao(dividirFracao(f1, f2))
    else:
        print("Opção invàlida")
# Out:
# Bem Vindo! :)
#     (1) Criar Fração
#     (2) Simplificar Fração
#     (3) Somar Fração
#     (4) Subtrair Fração
#     (5) Multiplicar Fração
#     (6) Dividir Fração
#     (0) Sair
